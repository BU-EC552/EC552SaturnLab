# %%
# this is a test script for a watson-integrated parts miner
# 
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, ConceptsOptions

authenticator = IAMAuthenticator('icmDJw0O-dSqYOoEcKwt-8j3uDsp22ULVfVFN_3fczSr')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2020-08-01',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.us-east.natural-language-understanding.watson.cloud.ibm.com/instances/b5ab2432-7e17-407e-a70a-2f10076a5ae4')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8f56d9276104> in <module>
# ----> 1 len(filtered_corpus)
#
# NameError: name 'filtered_corpus' is not defined

# %%
# read in practice corpus
import os
practice_corpus = []
corpus_dir = '/Users/cullenpaulisick/Documents/EC552/Project/EC552SaturnLab/WorkingCorpus'
os.chdir(corpus_dir)
for filename in os.listdir(os.getcwd()):
    with open(os.path.join(os.getcwd(), filename), 'r') as f:
        practice_corpus.append(f.read())
    f.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-c60b90df7408> in <module>
#       6 for filename in os.listdir(os.getcwd()):
#       7     with open(os.path.join(os.getcwd(), filename), 'r') as f:
# ----> 8         practice_corpus.append(f.read())
#       9     f.close()
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xca in position 561: invalid continuation byte

# %%
docs = list(practice_corpus)
# Tokenize the documents.
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
stop_words = stopwords.words('english') + ['fig', 'supplementary']
# Split the documents into tokens.
tokenizer = RegexpTokenizer(r'\w+')
for idx in range(len(docs)):
    docs[idx] = docs[idx].lower()  # Convert to lowercase.
    docs[idx] = tokenizer.tokenize(docs[idx])  # Split into words.
# Remove numbers, but not words that contain numbers.
docs = [[token for token in doc if not token.isnumeric()] for doc in docs]
# Remove words that are only one character.
docs = [[token for token in doc if len(token) > 2] for doc in docs]
# Remove stop words
docs = [[token for token in doc if token not in stop_words] for doc in docs]
# Lemmatize the documents.
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
docs = [[lemmatizer.lemmatize(token) for token in doc] for doc in docs]
filtered_corpus = [" ".join(doc) for doc in docs]

# %%
len(filtered_corpus)
# Out:
# 552

# %%
lemma_dir = '/Users/cullenpaulisick/Documents/EC552/Project/EC552SaturnLab/WorkingCorpus/LemmaCorpus'
os.chdir(lemma_dir)

# %%
for i, text in enumerate(filtered_corpus[:50]):
    if len(text) >= 40000:
        filtered_corpus[i] = text[:39998]

# %%
for i, file in enumerate(filtered_corpus[:50]):
    with open('file_' + str(i) + '.txt', 'w') as f:
        f.write(file)
    f.close()

# %%
for textfile in filtered_corpus[50:]:
    response = natural_language_understanding.analyze(
        text=textfile,
        features=Features(entities=EntitiesOptions(limit=10, model='116b1006-b509-463c-b13e-a57f7a6749f3'))
        ).get_result()

    print(json.dumps(response, indent=2))
# Out:
# : 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "ccl2",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.939444
#     },
#     {
#       "type": "Part",
#       "text": "mf59",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.83178
#     },
#     {
#       "type": "Part",
#       "text": "igg2a",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.757684
#     },
#     {
#       "type": "Part",
#       "text": "mf59",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.66563
#     },
#     {
#       "type": "Part",
#       "text": "igg1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.602729
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 5,
#     "text_characters": 41628,
#     "features": 1
#   },
#   "language": "en",
#   "entities": []
# }
# {
#   "usage": {
#     "text_units": 4,
#     "text_characters": 33500,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Method",
#       "text": "microfluidic reactor",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.906508
#     },
#     {
#       "type": "Part",
#       "text": "psc101",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.816172
#     },
#     {
#       "type": "Part",
#       "text": "5n2",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.752746
#     },
#     {
#       "type": "Part",
#       "text": "2xyt",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.71963
#     },
#     {
#       "type": "Part",
#       "text": "3n2",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.653241
#     },
#     {
#       "type": "Part",
#       "text": "cole1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.639758
#     },
#     {
#       "type": "Part",
#       "text": "5n1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.611071
#     },
#     {
#       "type": "Part",
#       "text": "3n1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.552331
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 5925,
#     "features": 1
#   },
#   "language": "en",
#   "entities": []
# }
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 27347,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "ylaro7",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.985725
#     },
#     {
#       "type": "Part",
#       "text": "ylpar4",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.968297
#     },
#     {
#       "type": "Part",
#       "text": "ylpha2",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.949137
#     },
#     {
#       "type": "Part",
#       "text": "ylaro10",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.931212
#     },
#     {
#       "type": "Method",
#       "text": "lithium acetate",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.827708
#     },
#     {
#       "type": "Part",
#       "text": "ylaro5",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.822675
#     },
#     {
#       "type": "Part",
#       "text": "scaro7",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.811036
#     },
#     {
#       "type": "Part",
#       "text": "scaro4",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.80118
#     },
#     {
#       "type": "Part",
#       "text": "ylaro4",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.800291
#     },
#     {
#       "type": "Part",
#       "text": "yl41",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.686375
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 27959,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Method",
#       "text": "fermentation",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.627774
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 14036,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "pkd3",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.947434
#     },
#     {
#       "type": "Part",
#       "text": "p15a",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.888092
#     },
#     {
#       "type": "Method",
#       "text": "fold induction",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.864936
#     },
#     {
#       "type": "Part",
#       "text": "mc261",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.858306
#     },
#     {
#       "type": "Method",
#       "text": "crispr",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.773509
#     },
#     {
#       "type": "Part",
#       "text": "mc262",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.684558
#     },
#     {
#       "type": "Part",
#       "text": "pte101",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.553418
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 20688,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "l73f",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.972673
#     },
#     {
#       "type": "Part",
#       "text": "l73f",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.938312
#     },
#     {
#       "type": "Part",
#       "text": "pacyc184",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.936419
#     },
#     {
#       "type": "Part",
#       "text": "p76a",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.924774
#     },
#     {
#       "type": "Part",
#       "text": "p76a",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.849111
#     },
#     {
#       "type": "Part",
#       "text": "l73f",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.830444
#     },
#     {
#       "type": "Part",
#       "text": "leu73",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.783372
#     },
#     {
#       "type": "Part",
#       "text": "pacyc177",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.734152
#     },
#     {
#       "type": "Part",
#       "text": "pl25",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.728193
#     },
#     {
#       "type": "Part",
#       "text": "pkd8",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.711779
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 6512,
#     "features": 1
#   },
#   "language": "en",
#   "entities": []
# }
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 23678,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "pao1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.984644
#     },
#     {
#       "type": "Part",
#       "text": "pao1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.978298
#     },
#     {
#       "type": "Part",
#       "text": "pao1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.971325
#     },
#     {
#       "type": "Part",
#       "text": "pao1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.963786
#     },
#     {
#       "type": "Part",
#       "text": "pao1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.953631
#     },
#     {
#       "type": "Part",
#       "text": "pao1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.944601
#     },
#     {
#       "type": "Part",
#       "text": "3oc12hsl",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.880666
#     },
#     {
#       "type": "Part",
#       "text": "3ochsl",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.838603
#     },
#     {
#       "type": "Part",
#       "text": "pao1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.837799
#     },
#     {
#       "type": "Method",
#       "text": "bradford assay",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.738389
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 22148,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Method",
#       "text": "oligonucleotide degradation",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.858341
#     },
#     {
#       "type": "Part",
#       "text": "gfp",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.817313
#     },
#     {
#       "type": "Part",
#       "text": "gfp",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.774403
#     },
#     {
#       "type": "Part",
#       "text": "prg1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.615764
#     },
#     {
#       "type": "Part",
#       "text": "gfp",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.570248
#     },
#     {
#       "type": "Part",
#       "text": "prg1",
#       "disambiguation": {
#         "subtype": [
#           "Gene"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.566827
#     },
#     {
#       "type": "Part",
#       "text": "gfp",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.560025
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 5,
#     "text_characters": 50000,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "\u03c370",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.98435
#     },
#     {
#       "type": "Part",
#       "text": "egfp",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.961071
#     },
#     {
#       "type": "Part",
#       "text": "od600",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.949262
#     },
#     {
#       "type": "Method",
#       "text": "riboswitch function",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.918568
#     },
#     {
#       "type": "Part",
#       "text": "l36",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.878444
#     },
#     {
#       "type": "Part",
#       "text": "l35",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.87761
#     },
#     {
#       "type": "Part",
#       "text": "l32",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.773116
#     },
#     {
#       "type": "Part",
#       "text": "\u03b4rs",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.518039
#     },
#     {
#       "type": "Part",
#       "text": "mkate2",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.507733
#     },
#     {
#       "type": "Part",
#       "text": "l30",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.482328
#     }
#   ],
#   "warnings": [
#     "Text content exceeds 50000 character limit. Only first 50000 characters processed..."
#   ]
# }
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 26626,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm2_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.970651
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm9_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.938358
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm8_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.921657
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm7_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.921657
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm6_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.921657
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm5_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.921657
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm3_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.879885
#     },
#     {
#       "type": "Part",
#       "text": "sp5x",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.575089
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm1_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.380564
#     },
#     {
#       "type": "Part",
#       "text": "41467_2020_15482_moesm4_esm",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.329091
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 16311,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "af647",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.850834
#     },
#     {
#       "type": "Part",
#       "text": "hn1ram8",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.731071
#     },
#     {
#       "type": "Part",
#       "text": "af488",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.662526
#     },
#     {
#       "type": "Part",
#       "text": "ram7",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.65954
#     },
#     {
#       "type": "Part",
#       "text": "\u03b1myc",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.657229
#     },
#     {
#       "type": "Part",
#       "text": "d2egfp",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.646089
#     },
#     {
#       "type": "Part",
#       "text": "\u03b1myc",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.412152
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 4,
#     "text_characters": 31506,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "p20",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.924814
#     },
#     {
#       "type": "Part",
#       "text": "p20",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.67197
#     },
#     {
#       "type": "Part",
#       "text": "neb5\u03b1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.597981
#     },
#     {
#       "type": "Part",
#       "text": "neb5\u03b1",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.595342
#     }
#   ]
# }
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 12929,
#     "features": 1
#   },
#   "language": "en",
#   "entities": []
# }
# {
#   "usage": {
#     "text_units": 3,
#     "text_characters": 27387,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Part",
#       "text": "mg1655",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.984511
#     },
#     {
#       "type": "Part",
#       "text": "5mc",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.808115
#     },
#     {
#       "type": "Part",
#       "text": "m6a",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.700499
#     },
#     {
#       "type": "Part",
#       "text": "sugar",
#       "disambiguation": {
#         "subtype": [
#           "NONE"
#         ]
#       },
#       "count": 1,
#       "confidence": 0.654518
#     }
#   ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-17f39122fe20> in <module>
#       1 for textfile in filtered_corpus[50:]:
# ----> 2     response = natural_language_understanding.analyze(
#       3         text=textfile,
#       4         features=Features(entities=EntitiesOptions(limit=10, model='116b1006-b509-463c-b13e-a57f7a6749f3'))
#       5         ).get_result()
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/ibm_watson/natural_language_understanding_v1.py in analyze(self, features, text, html, url, clean, xpath, fallback_to_raw, return_analyzed_text, language, limit_text_characters, **kwargs)
#     182                                        data=data)
#     183
# --> 184         response = self.send(request)
#     185         return response
#     186
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/ibm_cloud_sdk_core/base_service.py in send(self, request, **kwargs)
#     279
#     280         try:
# --> 281             response = self.http_client.request(**request,
#     282                                                 cookies=self.jar,
#     283                                                 **kwargs)
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/EC552Proj/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(practice_corpus[5])
# Out:
# 55692
